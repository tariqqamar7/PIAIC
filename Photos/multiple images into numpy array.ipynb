# %%
import numpy as np
import os
from PIL import Image

# %%
pwd
# Out:
# 'C:\\Users\\3tee\\Pictures\\Photos'

# %%
img = Image.open("1.jpg")
print(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x519 at 0x20D8F546CF8>

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x519 at 0x20D8F546CF8>

# %%
np_img = np.array(img)
print(np_img)
# Out:
# [[[ 1  2  4]
#   [ 1  2  4]
#   [ 1  2  4]
#   ...
#   [26 19 13]
#   [22 15  9]
#   [15  8  2]]
#
#  [[ 1  2  4]
#   [ 1  2  4]
#   [ 1  2  4]
#   ...
#   [21 14  8]
#   [21 14  8]
#   [18 11  5]]
#
#  [[ 1  2  4]
#   [ 1  2  4]
#   [ 1  2  4]
#   ...
#   [14  7  1]
#   [14  7  1]
#   [15  8  2]]
#
#  ...
#
#  [[37 45 47]
#   [29 37 39]
#   [42 50 52]
#   ...
#   [75 59 34]
#   [70 54 29]
#   [69 53 27]]
#
#  [[35 43 45]
#   [28 36 38]
#   [43 51 53]
#   ...
#   [78 62 37]
#   [73 57 32]
#   [64 48 22]]
#
#  [[36 44 46]
#   [31 39 41]
#   [44 52 54]
#   ...
#   [78 62 37]
#   [77 61 36]
#   [68 52 26]]]

# %%
root_dir = '/Users/3tee/Pictures/Photos/Photo'

# %%
resized = []
img = []
for dirName, subdirList, fileList in os.walk(root_dir):
    print('Found directory: %s' % dirName)
    for fname in fileList:
        a = Image.open(fname)
        img.append(a)
        for img in img:
            Img = img.resize((200,200))
            resized.append(Img)

# %%
saving_array = np.array(resized)
